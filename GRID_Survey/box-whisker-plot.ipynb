# %%
# library & dataset
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
csv_file = 'INITIA_SURVEY_ANALYSIS_RAW.csv'
df = pd.read_csv(csv_file)

# %%
# Make boxplot for one group only
box = sns.boxplot( y=df["Average Income - Coded (per 2 weeks)"], width =0.3)
sns.swarmplot( data=df["Average Income - Coded (per 2 weeks)"], color="yellow")
box.map(plt.axhline, y=10, ls='--', c='red')
# Out:
# C:\Users\louis\anaconda3\envs\Chem_NLP\lib\site-packages\seaborn\categorical.py:1282: RuntimeWarning: invalid value encountered in less
#   off_low = points < low_gutter
# C:\Users\louis\anaconda3\envs\Chem_NLP\lib\site-packages\seaborn\categorical.py:1286: RuntimeWarning: invalid value encountered in greater
#   off_high = points > high_gutter
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-9e41e3e622d9> in <module>
#       2 box = sns.boxplot( y=df["Average Income - Coded (per 2 weeks)"], width =0.3)
#       3 sns.swarmplot( data=df["Average Income - Coded (per 2 weeks)"], color="yellow")
# ----> 4 box.map(plt.axhline, y=10, ls='--', c='red')
#
# AttributeError: 'AxesSubplot' object has no attribute 'map'

# %%
sns.boxplot( y=df["Average income per week"] )

# %%
g = sns.catplot(x="fare", y="survived", row="class",
                kind="box", orient="h", height=1.5, aspect=4,
                data=tips)
g.set(xscale="log")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-68fb85b8c5d4> in <module>
#       1 g = sns.catplot(x="fare", y="survived", row="class",
#       2                 kind="box", orient="h", height=1.5, aspect=4,
# ----> 3                 data=tips)
#       4 g.set(xscale="log")
#
# NameError: name 'tips' is not defined

# %%
diamonds = sns.load_dataset("diamonds")
sns.catplot(x="color", y="price", kind="boxen",
            data=diamonds.sort_values("color"))

# %%
sns.catplot(y= "Average Income - Coded (per 2 weeks)" ,kind="box" ,data=df["Average Income - Coded (per 2 weeks)"], width =0.3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-59655d2bf5b4> in <module>
# ----> 1 sns.catplot(y= "Average Income - Coded (per 2 weeks)" ,kind="box" ,data=df["Average Income - Coded (per 2 weeks)"], width =0.3)
#
# ~\anaconda3\envs\Chem_NLP\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\envs\Chem_NLP\lib\site-packages\seaborn\categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3787     p = _CategoricalPlotter()
# ...
