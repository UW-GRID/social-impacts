# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-bright')
# %matplotlib inline

# %%
df = pd.read_csv('INITIA_SURVEY_ANALYSIS_RAW.csv')

# %%
#number of rows and columns in dataset
df.shape
# Out:
# (35, 68)

# %%
print(plt.style.available)
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']

# %%
df['Surveyor Name'].value_counts()
# Out:
# Estelle     21
# Griffin      5
# Giovanni     2
# Connor       1
# Whitney      1
# Conner       1
# Name: Surveyor Name, dtype: int64

# %%
df['Region/City'].value_counts(normalize=True)
# Out:
# Department of Escuintla (Sipacate)                   0.451613
# Department of Escuintla (La Gomera)                  0.290323
# Department of Sacatepéquez (Santa Maria de Jesus)    0.161290
# Department of Escuintla (Escuintla)                  0.064516
# Department of Chimaltenango (Labor de Falla)         0.032258
# Name: Region/City, dtype: float64

# %%
df['2. Gender'].value_counts(normalize=True)
# Out:
# Female    0.903226
# Male      0.096774
# Name: 2. Gender, dtype: float64

# %%
df['Age - Coded'].value_counts().plot(kind="hist")

# %%
df['3. Number of Household Occupants'].value_counts().plot(kind="hist")

# %%
df['4. Number of individuals making an income in household'].value_counts().plot(kind="hist")

# %%
df['5. Number of household that will use the panel'].value_counts()
# Out:
# 1.0    29
# 2.0     2
# Name: 5. Number of household that will use the panel, dtype: int64

# %%
df['Average Income - Coded (per 2 weeks)'].value_counts()
# Out:
# 1000.0    4
# 300.0     3
# 900.0     3
# 1200.0    2
# 100.0     2
# 400.0     2
# 500.0     2
# 650.0     2
# 1300.0    2
# 350.0     2
# 30.0      1
# 800.0     1
# 50.0      1
# 600.0     1
# 250.0     1
# 200.0     1
# 150.0     1
# Name: Average Income - Coded (per 2 weeks), dtype: int64

# %%
df['9. Does household have access to electricity?'].value_counts()
# Out:
# No     27
# Yes     4
# Name: 9. Does household have access to electricity?, dtype: int64

# %%
df[['Household occupations - Coded','Other common occupation - Coded']].value_counts().plot(kind='barh')

# %%
df['Household occupations - Coded'].head()
# Out:
# 0                      Food services
# 1        Construction worker/builder
# 2          Bus driver/transportation
# 3            Gardener, Domestic work
# 4    Farming (general/not specified)
# Name: Household occupations - Coded, dtype: object

# %%
df['Other common occupation - Coded'].head()
# Out:
# 0    Food processing factory worker
# 1                    Help at church
# 2                     Makes clothes
# 3                 Factory assembler
# 4                               NaN
# Name: Other common occupation - Coded, dtype: object

# %%
occupations = df[['Household occupations - Coded','Other common occupation - Coded']].split(',', expand=True)
occupations.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-049311c4c8f5> in <module>
# ----> 1 occupations = df[['Household occupations - Coded','Other common occupation - Coded']].split(',', expand=True)
#       2 occupations.head()
#
# ~\anaconda3\envs\Chem_NLP\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5128             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5129                 return self[name]
# -> 5130             return object.__getattribute__(self, name)
#    5131
#    5132     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'split'
